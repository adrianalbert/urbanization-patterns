# %% [markdown]
# # Initializations

# %%
import numpy as np
import pandas as pd

import sys, os, time
import glob

from matplotlib import pyplot as plt
# %matplotlib inline

# these magics ensure that external modules that are modified are also automatically reloaded
# %load_ext autoreload
# %autoreload 2

# widgets and interaction
from ipywidgets import FloatProgress
from IPython.display import display, clear_output

import seaborn as sns
sns.set_style("whitegrid", {'axes.grid' : False})

import warnings
warnings.filterwarnings('ignore')

import gzip
import cPickle as pickle

# %%
from IPython import parallel

rc = parallel.Client()
all_engines = rc[:]
lbv = rc.load_balanced_view()

print len(all_engines)
# Out:
# 48

# %%
# %%px --local
#
# import sys
# sys.path.append("/home/nbserver/urbanization-patterns/cityanalysis")
# from cityanalysis import City
# from cityanalysis import fractal_dimension

# %%
# %%px --local
#
# from skimage.transform import resize
# from skimage.io import imread, imsave
#
# def read_img(f, imgSize=None, scale=False):
#     img = imread(f)
#     if imgSize is not None:
#         img = resize(img, (imgSize, imgSize), preserve_range=True)
#     if scale:
#         img = (img - img.min()) / float((img.max() - img.min()))
#     return img

# %% [markdown]
# # Show stats on one example

# %% [markdown]
# First example: Paris, a radial, landlocked city with some lakes around.

# %%
myfile_SAR = '/home/data/world-cities/urban_areas_over_10kpop_raw/SAR_fr_paris,-fr-(pop-2.1M)_large_2110694_48.8667_2.3333.tif'
myfile_POP = '/home/data/world-cities/urban_areas_over_10kpop_raw/POP_fr_paris,-fr-(pop-2.1M)_large_2110694_48.8667_2.3333.tif'
myfile_NLI = '/home/data/world-cities/urban_areas_over_10kpop_raw/NLI_fr_paris,-fr-(pop-2.1M)_large_2110694_48.8667_2.3333.tif'
myfile_NLO = '/home/data/world-cities/urban_areas_over_10kpop_raw/NLO_fr_paris,-fr-(pop-2.1M)_large_2110694_48.8667_2.3333.tif'
myfile_WTR = '/home/data/world-cities/urban_areas_over_10kpop_raw/WTR_fr_paris,-fr-(pop-2.1M)_large_2110694_48.8667_2.3333.tif'
cityname = "Paris"

# %%
myfile_SAR = '/home/data/world-cities/urban_areas_over_10kpop_raw/SAR_ru_moscow,-ru-(pop-10.4M)_very-large_10381288_55.7522_37.6156.tif'
myfile_POP = '/home/data/world-cities/urban_areas_over_10kpop_raw/POP_ru_moscow,-ru-(pop-10.4M)_very-large_10381288_55.7522_37.6156.tif'
myfile_NLI = '/home/data/world-cities/urban_areas_over_10kpop_raw/NLI_ru_moscow,-ru-(pop-10.4M)_very-large_10381288_55.7522_37.6156.tif'
myfile_NLO = '/home/data/world-cities/urban_areas_over_10kpop_raw/NLO_ru_moscow,-ru-(pop-10.4M)_very-large_10381288_55.7522_37.6156.tif'
myfile_WTR = '/home/data/world-cities/urban_areas_over_10kpop_raw/NLO_ru_moscow,-ru-(pop-10.4M)_very-large_10381288_55.7522_37.6156.tif'
cityname = "Moscow"

# %%
myfile_SAR = '/home/data/world-cities/urban_areas_over_10kpop_raw/SAR_us_boston,-us-(pop-571.3k)_medium_571281_42.3583_-71.0603.tif'
myfile_POP = '/home/data/world-cities/urban_areas_over_10kpop_raw/POP_us_boston,-us-(pop-571.3k)_medium_571281_42.3583_-71.0603.tif'
myfile_NLI = '/home/data/world-cities/urban_areas_over_10kpop_raw/NLI_us_boston,-us-(pop-571.3k)_medium_571281_42.3583_-71.0603.tif'
myfile_NLO = '/home/data/world-cities/urban_areas_over_10kpop_raw/NLO_us_boston,-us-(pop-571.3k)_medium_571281_42.3583_-71.0603.tif'
myfile_WTR = '/home/data/world-cities/urban_areas_over_10kpop_raw/WTR_us_boston,-us-(pop-571.3k)_medium_571281_42.3583_-71.0603.tif'
cityname = "Boston"

# %%
myfile_SAR = '/home/data/world-cities/urban_areas_over_10kpop_raw/SAR_ng_lagos,-ng-(pop-8.8M)_very-large_8789133_6.4531_3.3958.tif'
myfile_POP = '/home/data/world-cities/urban_areas_over_10kpop_raw/POP_ng_lagos,-ng-(pop-8.8M)_very-large_8789133_6.4531_3.3958.tif'
myfile_NLI = '/home/data/world-cities/urban_areas_over_10kpop_raw/NLI_ng_lagos,-ng-(pop-8.8M)_very-large_8789133_6.4531_3.3958.tif'
myfile_NLO = '/home/data/world-cities/urban_areas_over_10kpop_raw/NLO_ng_lagos,-ng-(pop-8.8M)_very-large_8789133_6.4531_3.3958.tif'
myfile_WTR = '/home/data/world-cities/urban_areas_over_10kpop_raw/WTR_ng_lagos,-ng-(pop-8.8M)_very-large_8789133_6.4531_3.3958.tif'
cityname = "Lagos"

# %%
img = []
for f in [myfile_SAR, myfile_POP, myfile_NLI, myfile_NLO]:
    img.append(read_img(f))
img = np.concatenate([a[...,np.newaxis] for a in img], axis=2)
   
mask = read_img(myfile_WTR,scale=True)

mycity = City(img, name=cityname, mask=mask, 
              sources=["built", "pop", "lum", "lum-old"])

# %%
fig, ax = plt.subplots(1,2,figsize=(8,4))
ax[0].imshow(mycity.M); 
ax[0].axis("off"); ax[0].set_title("%s: built+pop+lum" % mycity.name)

ax[1].imshow(np.isnan(mycity.mask)); 
ax[1].axis("off"); ax[1].set_title("%s: water mask" % mycity.name)

# %%
fig, ax = plt.subplots(1,2,figsize=(10,4))
ax[0].imshow(mask); 
ax[0].axis("off"); ax[0].set_title("Water Mask: %s" % mycity.name)

ax[1].hist(mask.flatten()); 
ax[1].set_title("%s: water mask" % mycity.name)

# %% [markdown]
# #### Fraction of occupied area

# %%
mycity.compute_average()
mycity.avg_areas
# Out:
# {'built': 0.087844808196435295,
#  'lum': 3.6553528060659075,
#  'lum-old': 30.103545433177135,
#  'pop': 208.05717688102371}

# %%
mycity.sum_areas
# Out:
# {'built': 7185.1782416192282,
#  'lum': 298985.92741935485,
#  'lum-old': 2462289.3951612907,
#  'pop': 17017828.725806452}

# %% [markdown]
# #### Distribution of patch areas

# %%
sns.set_context("notebook", font_scale=1.5)

mycity.compute_regions()
areas = mycity.regions['built']
areas_distr, bins = mycity.areas_distr['built'][0], mycity.areas_distr['built'][1]

# plot just top 5 areas
mask1 = mycity.masks_regions['built'].copy()
for a in areas[5:]:
    mask1[mask1==a[0]] = 0

fig, ax = plt.subplots(1,2, figsize=(8,4))
imgplot = ax[0].imshow(mask1)
imgplot.set_cmap('BrBG')
ax[0].set_title("%s: 256x256 px" % mycity.name)
ax[0].axis("off")

# plot distribution of area sizes
ax[1].scatter(np.log(bins), areas_distr, marker="o")
ax[1].set_title("Distribution of area patches")
ax[1].set_ylabel("log(N)")
ax[1].set_xlabel("log(area)")

plt.tight_layout()

# %% [markdown]
# #### Fractal dimension

# %%
I = read_img("sierpinski.png")
plt.imshow(1-I)
plt.axis("off")
plt.title("Box counting: \nSierpinski's triangle (f=%2.2f)"%fractal_dimension(I)[0], 
          fontsize=22)

print("Minkowski-Bouligand dimension (computed): ", fractal_dimension(I)[0])
print("Haussdorf dimension (theoretical):        ", (np.log(3)/np.log(2)))
# Out:
# ('Minkowski-Bouligand dimension (computed): ', nan)
# ('Haussdorf dimension (theoretical):        ', 1.5849625007211563)

# %%
frac_dim = mycity.compute_fractal_dim(0)
print mycity.fractal_dim

_, log_box_sizes, log_box_counts = fractal_dimension(mycity.M[:,:,0])
# Out:
# {'built': 1.6217487936805015}

# %%
sns.set_context("notebook", font_scale=1.5)
fig = plt.figure(figsize=(4,4))
ax = sns.regplot(log_box_sizes, log_box_counts, lowess=False)
plt.xlabel("log (box size)")
plt.ylabel("log (box count)")
plt.title("Fractal dim. $f$ for %s" % mycity.name)

ax.annotate('$f=$%.2f'%frac_dim['built'], xy=(2, 1), xytext=(3, 1.5))

# %% [markdown]
# #### Compute distance profiles

# %%
profiles = mycity.compute_profile(method="raysampling")

xlabels = np.arange(20) * 10 * 200 / 286.0

plt.figure(figsize=(6,4))
for c,p in profiles.iteritems():
    plt.plot(xlabels, p[0], label=c, lw=2)
plt.legend(loc="best")
plt.title("Distance curves for %s"%mycity.name)
plt.xlabel("$d \ [km]$")

# %%
# using radial estimation method

profiles = mycity.compute_profile(method="radial", step=1.333)

xlabels = np.arange(len(profiles.values()[0][0])) * 10 * 200 / 286.0

plt.figure(figsize=(6,4))
for c,p in profiles.iteritems():
    plt.plot(xlabels, p[0], label=c, lw=2)
plt.legend(loc="best")
plt.title("Distance curves for %s"%mycity.name)
plt.xlabel("$d \ [km]$")

# %%
plt.plot(mycity.profiles['pop'][0] / mycity.profiles['built'][0])

# %%
plt.plot(mycity.profiles['lum'][0] / mycity.profiles['built'][0])

# %%
plt.plot(mycity.profiles['built'][0] / mycity.profiles['pop'][0] )

# %%
plt.plot(mycity.profiles['lum'][0] / mycity.profiles['pop'][0] )

# %% [markdown]
# # Compute spatial stats across all cities

# %% [markdown]
# #### Gather all data sources

# %%
dataroot = "/home/data/world-cities/"

# %%
regions_df = pd.read_csv(dataroot + "countries_regions.csv")

country2region = {r:c for r,c in zip(regions_df['alpha-2'].str.lower(), regions_df['region'])}
country2subregion = {r:c for r,c in zip(regions_df['alpha-2'].str.lower(), regions_df['sub-region'])}

# %%
import glob

files = glob.glob(dataroot + "urban_areas_over_10kpop_raw/*.tif")
files_df = []
for f in files:
    s = f.split("/")
    fname = s[-1]
    cls = fname.split("_")[3]
    _,country,city,_,pop,lat,lon = fname.split("_")
    files_df.append((f, cls, country, pop))
    
files_df = pd.DataFrame(files_df, \
                columns=["filename", "class", "country", "population"])
files_df['city'] = files_df['filename'].apply(lambda s: os.path.basename(s).split("_")[2].replace("-"," "))
files_df['region'] = files_df['country'].apply(lambda x: country2region[x] if x in country2region else np.nan)
files_df['source'] = files_df['filename'].apply(lambda s: os.path.basename(s).split("_")[0])

len(files_df)
# Out:
# 125120

# %%
files_df.head(2)
# Out:
#                                             filename       class country  \
# 0  /home/data/world-cities/urban_areas_over_10kpo...  very-small      us
# 1  /home/data/world-cities/urban_areas_over_10kpo...  very-small      ci
#
#   population                     city    region source
# 0      13429   geneva, us (pop 13.4k)  Americas    NLI
# 1      25351  mankono, ci (pop 25.4k)    Africa    SAR

# %%
sources = files_df.groupby("city").apply(\
                    lambda x: (x[['city', 'country', 'region', 'population', 'class']].iloc[0].to_dict(), 
                               dict(zip(x['source'], x['filename']))))
filenames = [s[1] for s in sources]
info = [s[0] for s in sources]
print sources[0]
# Out:
# ({'city': 'a coruna, es (pop 236.0k)', 'region': 'Europe', 'population': '236010', 'class': 'small-2', 'country': 'es'}, {'NLI': '/home/data/world-cities/urban_areas_over_10kpop_raw/NLI_es_a-coruna,-es-(pop-236.0k)_small-2_236010_43.3666_-8.4068.tif', 'SAR': '/home/data/world-cities/urban_areas_over_10kpop_raw/SAR_es_a-coruna,-es-(pop-236.0k)_small-2_236010_43.3666_-8.4068.tif', 'WTR': '/home/data/world-cities/urban_areas_over_10kpop_raw/WTR_es_a-coruna,-es-(pop-236.0k)_small-2_236010_43.3666_-8.4068.tif', 'NLO': '/home/data/world-cities/urban_areas_over_10kpop_raw/NLO_es_a-coruna,-es-(pop-236.0k)_small-2_236010_43.3666_-8.4068.tif', 'POP': '/home/data/world-cities/urban_areas_over_10kpop_raw/POP_es_a-coruna,-es-(pop-236.0k)_small-2_236010_43.3666_-8.4068.tif'})

# %%
sources[0]
# Out:
# ({'city': 'a coruna, es (pop 236.0k)',
#   'class': 'small-2',
#   'country': 'es',
#   'population': '236010',
#   'region': 'Europe'},
#  {'NLI': '/home/data/world-cities/urban_areas_over_10kpop_raw/NLI_es_a-coruna,-es-(pop-236.0k)_small-2_236010_43.3666_-8.4068.tif',
#   'NLO': '/home/data/world-cities/urban_areas_over_10kpop_raw/NLO_es_a-coruna,-es-(pop-236.0k)_small-2_236010_43.3666_-8.4068.tif',
#   'POP': '/home/data/world-cities/urban_areas_over_10kpop_raw/POP_es_a-coruna,-es-(pop-236.0k)_small-2_236010_43.3666_-8.4068.tif',
#   'SAR': '/home/data/world-cities/urban_areas_over_10kpop_raw/SAR_es_a-coruna,-es-(pop-236.0k)_small-2_236010_43.3666_-8.4068.tif',
#   'WTR': '/home/data/world-cities/urban_areas_over_10kpop_raw/WTR_es_a-coruna,-es-(pop-236.0k)_small-2_236010_43.3666_-8.4068.tif'})

# %% [markdown]
# #### Compute stats in parallel

# %%
# %%px --local
#
# import numpy as np
#
# def compute_stats(filenames):
#     img = []
#     for f in [filenames['SAR'], filenames['POP'], filenames['NLI']]:
#         img.append(read_img(f))
#     img = np.concatenate([a[...,np.newaxis] for a in img], axis=2)
#     mask = read_img(f, scale=True)
#     city = City(img, mask=mask, sources=["bldg", "pop", "lum"])
#     try:
#         city.analyze()
#         return {"profiles":city.profiles,
#                 "frac dim":city.fractal_dim,
#                 "avg area":city.avg_areas,
#                 "sum area":city.sum_areas,
#                 "area dis":city.areas_distr}
#     except:
#         return None

# %%
# %%timeit
info = compute_stats(filenames[1])

# %%
res = lbv.map_async(lambda src: compute_stats(src), filenames)

# %%
res.progress

# %%
idx_ok = [r is not None for i,r in enumerate(res.result()) ]
tot = dict(zip([i['city'] for i,ok in zip(info, idx_ok) if ok], 
         [dict(i.items() + d.items()) for i,d,ok in zip(info,res.result(), idx_ok) if ok]))

len(idx_ok), sum(idx_ok)

# %% [markdown]
# #### Save to file

# %%
with gzip.open(dataroot + "stats_25k_cities_raw.pickle.gz", "w") as f:
    pickle.dump(tot, f)

# %% [markdown]
# # Analyze spatial statistics over all cities

# %%
# with gzip.open(dataroot + "stats_25k_cities.pickle.gz", "r") as f:
#     tot = pickle.load(f)

# %% [markdown]
# Average built area $a$

# %%
a_sar = np.array([v['avg area']['bldg'] for k,v in tot.iteritems()])

sns.set_context("notebook", font_scale=1.5)
plt.figure(figsize=(6,4))
_ = plt.hist(a_sar, bins=100, range=(0,0.2))
plt.title("Built area $a$")
plt.xlabel("$a$")

# %% [markdown]
# Fractal dimension $f$

# %%
f_sar = np.array([v['frac dim']['bldg'] for k,v in tot.iteritems()])

sns.set_context("notebook", font_scale=1.5)
plt.figure(figsize=(6,4))
_ = plt.hist(f_sar, bins=100)
plt.title("Fractal dimension $f$")
plt.xlabel("$f$")

# %%
from scipy.stats import kendalltau
sns.set_context("notebook", font_scale=1.5)
sns.set(style="ticks")

plt.figure(figsize=(6,4))
g = sns.jointplot(a_sar, f_sar, xlim=(0,0.1), ylim=(0.9,1.7),
              kind="hex", stat_func=kendalltau, color="#4CB391")
g.fig.suptitle("Built area $a$ vs fractal dimension $f$", fontsize=16)
g.ax_joint.set_xlabel("$a$", fontsize=16)
g.ax_joint.set_ylabel("$f$", fontsize=16)

# %%
a_sar.shape
